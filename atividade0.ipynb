# %% [markdown]
# <a href="https://colab.research.google.com/github/L-jsA/AULAS-GEN---GIT/blob/main/atividade0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importando as bibliotecas para o sistema
#
#
# *   pandas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %% [markdown]
# Com esse notebook vamos:
#
#
# *   carregar as bases de dados;
# *   limpar dados;
# *   mesclagem de dados (merge);
# *   agrupamento de dados (groupby);
# *   tabela dinâmica.

# %% [markdown]
# Base de dados "sales_data" csv

# %%
df_sales_data = pd.read_csv('/sales_data.csv')
print(df_sales_data)
# Out:
#    SaleID  Product_ID  Quantity  Price    SaleDate
# 0       1         101         2  19.99  2024-11-01
# 1       2         102         1  29.99  2024-11-02
# 2       3         103         3    NaN  2024-11-03
# 3       4         101         5  19.99  2024-11-04
# 4       5         104         2  39.99  2024-11-05

# %% [markdown]
# Base de dados "product_inventory" exel

# %%
df_product_inventory = pd.read_excel('/content/product_inventory.xlsx')
display(df_product_inventory)

# %% [markdown]
# Completar dados de "price"ausentes com média do campo

# %%
# calculo de média
media_precos = df_sales_data['Price'].mean()

# colocando o valor dentro da tabela
df_sales_data['Price'] = df_sales_data['Price'].fillna(media_precos)

# exibir dados
display(df_sales_data)

# %% [markdown]
# Relatório com vendas e produtos

# %%
# Renomear a coluna df_product
df_product_inventory.rename(columns={'ProductID': 'Product_ID'}, inplace=True)

relatorio_final = pd.merge(df_sales_data, df_product_inventory, on='Product_ID')

# Criar um novo campo - valor venda
relatorio_final['Total_da_venda'] = relatorio_final['Quantity'] * relatorio_final['Price']
display(relatorio_final)

# Salvando em excel
relatorio_final.to_csv('relatorio_final.csv', index=False)

# %%
# !git clone https://github.com/L-jsA/AULAS-GEN---GIT.git
# %cd AULAS-GEN---GIT
# !git add.
# !git commit -m "Código no Google Colab"
# !gitpush
# Out:
# Cloning into 'AULAS-GEN---GIT'...
# remote: Enumerating objects: 103, done.
# remote: Counting objects: 100% (103/103), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 103 (delta 14), reused 94 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (103/103), 834.52 KiB | 11.92 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# /content/AULAS-GEN---GIT/AULAS-GEN---GIT/AULAS-GEN---GIT/AULAS-GEN---GIT/AULAS-GEN---GIT
# git: 'add.' is not a git command. See 'git --help'.
#
# The most similar command is
# 	add
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@c9e1186bff5a.(none)')
# /bin/bash: line 1: gitpush: command not found
